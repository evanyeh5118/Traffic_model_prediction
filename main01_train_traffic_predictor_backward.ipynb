# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import numpy as np
import matplotlib.pyplot as plt
import pickle
import torch

from libs.TrafficGenerator import DatasetConvertor 
from libs.TrafficPredictor.ContextAssisted import PreparingDataset as PreparingDatasetCA
from libs.TrafficPredictor.ContextAssisted import trainModelByDefaultSetting as trainModelCA
from libs.TrafficPredictor.ContextAssisted import evaluateModel as evaluateModelCA
from libs.TrafficPredictor.ContextAssisted import createModel as createModelCA
from libs import encode_float_filename, decode_float_filename

# %%
stringFile = encode_float_filename(0.5)
floatFile = decode_float_filename(stringFile)
print(stringFile)
print(floatFile)
# Out:
# 5_00e-01.txt
# 0.5

# %%
#dbParams = 0.01
#direction = "forward"
dbParams = 0.2
direction = "backward"
mode = "fixed"

rawDatasetFolder = "Dataset"
datasetConverter = DatasetConvertor(rawDatasetFolder)
datasetConverter.processDataset(dbParameter=dbParams, alpha=dbParams, mode="fixed", direction=direction)
#thumbUnit = datasetConverter.getDataUnit('thumb_fr')
thumbUnit = datasetConverter.getDataUnit('thumb_bk')
# Out:
# ========== thumb ============
# Backward: Compression rate:0.2032248455322052
# ========== index ============
# Backward: Compression rate:0.18577454908856794
# ========== middle ============
# Backward: Compression rate:0.19320245611000605

# %%
lenWindow = 10
trainDataAugment = True
verbose = True

paramsCA = {}
paramsCA['lenSource'] = lenWindow
paramsCA['lenTarget'] = lenWindow
paramsCA['trainRatio'] = 0.5
paramsCA['dataAugment'] = trainDataAugment
paramsCA['smoothFc'] = 1.5
paramsCA['smoothOrder'] = 3
trainData, testData = PreparingDatasetCA(thumbUnit, paramsCA, verbose=verbose)

(sources, _, lastTranmittedContext, _, _, _, _) = trainData
print(sources.shape)
print(lastTranmittedContext.shape)
# Out:
# Train size: 52033, Test size: 52034
# (52013, 10, 1)
# (52013, 1, 1)

# %%
bestWeightsCA, _, _, modleParametersCA = trainModelCA(
paramsCA['lenSource'], paramsCA['lenTarget'], trainData, testData, verbose=verbose)
# Out:
# Size of train loader: 13, Size of test loader: 13
# Used device: cuda
# Size of model: 837774
# TrafficPredictorContextAssisted(
#   (dbf2traffic): DeadFeaturesToTrafficLayer(
#     (input_layer): Sequential(
#       (0): Linear(in_features=66, out_features=512, bias=True)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.9, inplace=False)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): Linear(in_features=512, out_features=512, bias=True)
#         (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.9, inplace=False)
#       )
#     )
#     (trans2transmission_layer): Linear(in_features=512, out_features=10, bias=True)
#     (sigmoid): Sigmoid()
#     (trans2traffic_layer): Linear(in_features=522, out_features=1, bias=True)
#     (trans2trafficClass_layer): Linear(in_features=522, out_features=11, bias=True)
#   )
#   (reluOut): ReLU()
# )
# Epoch [1/50], Train Loss: 5341.0832, Validation Loss: 1943.2082, Validation Loss (Traffic): 7.1994
# Epoch [2/50], Train Loss: 2846.5292, Validation Loss: 1886.2693, Validation Loss (Traffic): 7.1994
# Epoch [3/50], Train Loss: 2234.4914, Validation Loss: 1819.5281, Validation Loss (Traffic): 7.1994
# Epoch [4/50], Train Loss: 2015.4125, Validation Loss: 1835.9516, Validation Loss (Traffic): 7.1994
# Epoch [5/50], Train Loss: 1957.7708, Validation Loss: 1790.0263, Validation Loss (Traffic): 7.1994
# Epoch [6/50], Train Loss: 1903.3508, Validation Loss: 1762.6518, Validation Loss (Traffic): 7.1994
# Epoch [7/50], Train Loss: 1864.7418, Validation Loss: 1762.9223, Validation Loss (Traffic): 7.1994
# Epoch [8/50], Train Loss: 1837.1978, Validation Loss: 1749.5204, Validation Loss (Traffic): 7.1994
# Epoch [9/50], Train Loss: 1827.1541, Validation Loss: 1748.7768, Validation Loss (Traffic): 7.1994
# Epoch [10/50], Train Loss: 1820.4104, Validation Loss: 1752.4554, Validation Loss (Traffic): 7.1994
# Epoch [11/50], Train Loss: 1817.4889, Validation Loss: 1743.4089, Validation Loss (Traffic): 7.1994
# Epoch [12/50], Train Loss: 1819.0040, Validation Loss: 1743.5914, Validation Loss (Traffic): 7.1994
# Epoch [13/50], Train Loss: 1822.6710, Validation Loss: 1743.6677, Validation Loss (Traffic): 7.1994
# Epoch [14/50], Train Loss: 1811.7924, Validation Loss: 1726.3128, Validation Loss (Traffic): 7.1994
# Epoch [15/50], Train Loss: 1809.9904, Validation Loss: 1730.9340, Validation Loss (Traffic): 7.1994
# Epoch [16/50], Train Loss: 1800.7028, Validation Loss: 1723.2344, Validation Loss (Traffic): 7.1994
# Epoch [17/50], Train Loss: 1792.3541, Validation Loss: 1725.2353, Validation Loss (Traffic): 7.1994
# Epoch [18/50], Train Loss: 1792.8044, Validation Loss: 1717.6110, Validation Loss (Traffic): 7.1994
# Epoch [19/50], Train Loss: 1795.9819, Validation Loss: 1725.8169, Validation Loss (Traffic): 7.1994
# Epoch [20/50], Train Loss: 1791.5244, Validation Loss: 1726.2942, Validation Loss (Traffic): 7.1994
# Epoch [21/50], Train Loss: 1799.5373, Validation Loss: 1714.9202, Validation Loss (Traffic): 7.1994
# Epoch [22/50], Train Loss: 1790.4369, Validation Loss: 1718.4062, Validation Loss (Traffic): 7.1994
# Epoch [23/50], Train Loss: 1781.1431, Validation Loss: 1714.5832, Validation Loss (Traffic): 7.1994
# Epoch [24/50], Train Loss: 1771.7509, Validation Loss: 1717.4217, Validation Loss (Traffic): 7.1994
# Epoch [25/50], Train Loss: 1771.3271, Validation Loss: 1709.7925, Validation Loss (Traffic): 6.9620
# Epoch [26/50], Train Loss: 1772.9273, Validation Loss: 1704.2100, Validation Loss (Traffic): 4.0021
# Epoch [27/50], Train Loss: 1768.3462, Validation Loss: 1713.9119, Validation Loss (Traffic): 3.0051
# Epoch [28/50], Train Loss: 1773.3989, Validation Loss: 1722.0008, Validation Loss (Traffic): 2.6807
# Epoch [29/50], Train Loss: 1780.0769, Validation Loss: 1709.1922, Validation Loss (Traffic): 2.6448
# Epoch [30/50], Train Loss: 1764.3540, Validation Loss: 1706.9026, Validation Loss (Traffic): 2.5134
# Epoch [31/50], Train Loss: 1758.5926, Validation Loss: 1700.2265, Validation Loss (Traffic): 2.5555
# Epoch [32/50], Train Loss: 1756.3654, Validation Loss: 1699.6333, Validation Loss (Traffic): 2.4029
# Epoch [33/50], Train Loss: 1757.1787, Validation Loss: 1693.3321, Validation Loss (Traffic): 2.4602
# Epoch [34/50], Train Loss: 1755.9129, Validation Loss: 1697.4468, Validation Loss (Traffic): 2.4290
# Epoch [35/50], Train Loss: 1759.3213, Validation Loss: 1694.3138, Validation Loss (Traffic): 2.4242
# Epoch [36/50], Train Loss: 1754.1078, Validation Loss: 1689.2310, Validation Loss (Traffic): 2.3781
# Epoch [37/50], Train Loss: 1745.4355, Validation Loss: 1693.6151, Validation Loss (Traffic): 2.3702
# Epoch [38/50], Train Loss: 1742.5275, Validation Loss: 1690.8137, Validation Loss (Traffic): 2.3984
# Epoch [39/50], Train Loss: 1742.6259, Validation Loss: 1686.5662, Validation Loss (Traffic): 2.3689
# Epoch [40/50], Train Loss: 1741.6655, Validation Loss: 1695.3281, Validation Loss (Traffic): 2.3550
# Epoch [41/50], Train Loss: 1736.8631, Validation Loss: 1684.1506, Validation Loss (Traffic): 2.3342
# Epoch [42/50], Train Loss: 1736.6309, Validation Loss: 1695.2083, Validation Loss (Traffic): 2.3250
# Epoch [43/50], Train Loss: 1733.6376, Validation Loss: 1694.4758, Validation Loss (Traffic): 2.3239
# Epoch [44/50], Train Loss: 1736.0672, Validation Loss: 1680.9646, Validation Loss (Traffic): 2.3207
# Epoch [45/50], Train Loss: 1736.3030, Validation Loss: 1680.7426, Validation Loss (Traffic): 2.3316
# Epoch [46/50], Train Loss: 1738.1749, Validation Loss: 1701.6084, Validation Loss (Traffic): 2.3188
# Epoch [47/50], Train Loss: 1737.6507, Validation Loss: 1689.5884, Validation Loss (Traffic): 2.3147
# Epoch [48/50], Train Loss: 1731.9056, Validation Loss: 1693.9218, Validation Loss (Traffic): 2.3166
# Epoch [49/50], Train Loss: 1728.0316, Validation Loss: 1682.0251, Validation Loss (Traffic): 2.3177
# Epoch [50/50], Train Loss: 1730.2596, Validation Loss: 1677.0172, Validation Loss (Traffic): 2.3104

# %%
trafficModelCA, _ = createModelCA(modleParametersCA)
trafficModelCA.load_state_dict(bestWeightsCA)

paramsValid = paramsCA.copy()
paramsValid['dataAugment'] = False
trainData, testData = PreparingDatasetCA(thumbUnit, paramsValid, verbose=verbose)
#(actual_trafficCA_train, predicted_trafficCA_train, actual_class_train, predicted_class_train, _, _, _, _)  = evaluateModelCA(trafficModelCA, trainData)
#(actual_trafficCA_test, predicted_trafficCA_test, actual_class_test, predicted_class_test, _, _, _, _)  = evaluateModelCA(trafficModelCA, trainData)
resultsTrain = evaluateModelCA(trafficModelCA, trainData)
resultsTest = evaluateModelCA(trafficModelCA, testData)

print(f"actual_class_shape: {resultsTrain['classDistribu_actual'].shape}, predicted_class_shape: {resultsTrain['classDistribu_predicted'].shape}")

plt.plot(resultsTest['trafficTarget_actual'][0:200])
plt.plot(resultsTest['trafficTarget_predicted'][0:200])
# Out:
# Train size: 52033, Test size: 52034
# actual_class_shape: (5201, 1), predicted_class_shape: (5201, 11)

# %%
dbpString = encode_float_filename(dbParams)
with open(f"Results/TrafficPredictor/evaluate/{direction}_{lenWindow}_{mode}_{dbpString}_train.pkl", "wb") as file:
    pickle.dump(resultsTrain, file)
with open(f"Results/TrafficPredictor/evaluate/{direction}_{lenWindow}_{mode}_{dbpString}_test.pkl", "wb") as file:
    pickle.dump(resultsTest, file)

#modelData = {}
#modelData["trainData"] = trainData
#modelData["testData"] = testData
#with open(f"Results/TrafficPredictor/modelData/{direction}_{lenWindow}_{mode}_{dbpString}.pkl", "wb") as file:
#    pickle.dump(modelData, file)
with open(f"Results/TrafficPredictor/modelParams/{direction}_{lenWindow}_{mode}_{dbpString}.pkl", "wb") as file:
    pickle.dump(modleParametersCA, file)
torch.save(bestWeightsCA, f"Results/TrafficPredictor/model/{direction}_{lenWindow}_{mode}_{dbpString}.pth")
